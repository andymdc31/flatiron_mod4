# %% [markdown]
# # Scrubbing and Cleaning Data - Lab
#
# ## Introduction
#
# In the previous labs, you joined the data from our separate files into a single DataFrame.  In this lab, you'll scrub the data to get it ready for exploration and modeling!
#
# ## Objectives
#
# You will be able to:
#
# * Cast columns to the appropriate data types
# * Identify and deal with null values appropriately
# * Remove unnecessary columns
# * Understand how to normalize data
#
#
# ## Getting Started
#
# You'll find the resulting dataset from your work in the _Obtaining Data_ Lab stored within the file `'Lego_data_merged.csv'`.
#
# In the cells below:
#
# * Import `pandas` and set the standard alias.
# * Import `numpy` and set the standard alias.
# * Import `matplotlib.pyplot` and set the standard alias.
# * Import `seaborn` and set the alias `sns` (this is the standard alias for seaborn).
# * Use the ipython magic command to set all matplotlib visualizations to display inline in the notebook.
# * Load the dataset stored in the `'Lego_data_merged.csv'` file into a DataFrame, `df`.
# * Inspect the head of the DataFrame to ensure everything loaded correctly.

# %%
# Import statements go here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Now, load in the dataset and inspect the head to make sure everything loaded correctly
df = pd.read_csv('Lego_data_merged.csv')
df.head()
# Out:
#    prod_id  ages  piece_count                        set_name  \
# 0    75823  6-12          277           Bird Island Egg Heist
# 1    75822  6-12          168              Piggy Plane Attack
# 2    75821  6-12           74                Piggy Car Escape
# 3    21030   12+         1032  United States Capitol Building
# 4    21035   12+          744   Solomon R. Guggenheim Museum®
#
#                                            prod_desc  \
# 0  Catapult into action and take back the eggs fr...
# 1  Launch a flying attack and rescue the eggs fro...
# 2  Chase the piggy with lightning-fast Chuck and ...
# 3  Explore the architecture of the United States ...
# 4  Recreate the Solomon R. Guggenheim Museum® wit...
#
#                                       prod_long_desc    theme_name country  \
# 0  Use the staircase catapult to launch Red into ...  Angry Birds™      US
# 1  Pilot Pig has taken off from Bird Island with ...  Angry Birds™      US
# 2  Pitch speedy bird Chuck against the Piggy Car....  Angry Birds™      US
# 3  Discover the architectural secrets of the icon...  Architecture      US
# 4  Discover the architectural secrets of Frank Ll...  Architecture      US
#
#   list_price  num_reviews  play_star_rating review_difficulty  star_rating  \
# 0     $29.99          2.0               4.0           Average          4.5
# 1     $19.99          2.0               4.0              Easy          5.0
# 2     $12.99         11.0               4.3              Easy          4.3
# 3     $99.99         23.0               3.6           Average          4.6
# 4     $79.99         14.0               3.2       Challenging          4.6
#
#    val_star_rating
# 0              4.0
# 1              4.0
# 2              4.1
# 3              4.3
# 4              4.1

# %% [markdown]
# ## Starting our Data Cleaning
#
# To start, you'll deal with the most obvious issue: data features with the wrong data encoding.
#
# ### Checking Data Types
#
# In the cell below, use the appropriate method to check the data type of each column.

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10512 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null object
# num_reviews          9449 non-null float64
# play_star_rating     9321 non-null float64
# review_difficulty    9104 non-null object
# star_rating          9449 non-null float64
# val_star_rating      9301 non-null float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# Now, investigate some of the unique values inside of the `list_price` column.

# %%
# Your code here
df.list_price.unique()
# Out:
# array(['$29.99', '$19.99', '$12.99', '$99.99', '$79.99', '$59.99',
#        '$49.99', '$39.99', '$34.99', '$159.99', '$9.99', '$199.99',
#        '$149.99', '$119.99', '$89.99', '$69.99', '$24.99', '$15.99',
#        '$14.99', '$6.99', '$16.99', '$7.99', '$4.99', '$2.49', '$369.99',
#        '$169.99', '$279.99', '$249.99', '$239.99', '$139.99', '$269.99',
#        '$129.99', '$44.99', '$11.99', '$349.99', '$5.99', '$109.99',
#        '$54.99', '$32.99', '$197.99', '$88.99', '$41.99', '$31.99',
#        '$26.99', '$21.99', '$3.99', '$299.99', '$754.99', '$484.99',
#        '$36.99', '$789.99', '$499.99', '$84.99', '$799.99', '$289.99',
#        '$179.99', '$113.9924', '$75.9924', '$60.7924', '$53.1924',
#        '$45.59240000000001', '$37.9924', '$189.9924', '$30.3924',
#        '$22.7924', '$12.1524', '$227.9924', '$174.7924', '$121.5924',
#        '$34.1924', '$18.9924', '$17.4724', '$13.6724', '$7.5924',
#        '$15.1924', '$9.8724', '$6.0724', '$2.2724', '$91.1924',
#        '$379.9924', '$303.9924000000001', '$288.7924',
#        '$265.99240000000003', '$220.3924', '$151.9924',
#        '$129.19240000000002', '$83.5924', '$136.7924', '$26.5924',
#        '$53.162000000000006', '$37.962', '$30.362', '$18.962', '$41.7924',
#        '$11.3924', '$68.3924', '$250.7924', '$26.6', '$4.5524',
#        '$144.3924', '$197.5924', '$106.3924', '$645.9924', '$607.9924',
#        '$395.1924', '$29.6324', '$205.1924', '$98.7924', '$987.9924',
#        '$167.19240000000005', '$25.0724', '$121.9878', '$85.3878',
#        '$73.1878', '$60.9878', '$48.7878', '$42.6878', '$36.5878',
#        '$195.1878', '$24.3878', '$12.1878', '$219.5878',
#        '$158.58780000000004', '$146.3878', '$109.7878', '$97.5878',
#        '$21.9478', '$18.2878', '$7.3078', '$30.4878', '$9.7478',
#        '$6.0878000000000005', '$3.0378000000000003', '$54.8878',
#        '$182.9878', '$402.5878', '$292.7878', '$268.3878', '$329.3878',
#        '$426.9878', '$243.9878', '$79.28779999999998', '$67.0878',
#        '$40.2478', '$15.8478', '$28.0478', '$19.5078', '$304.9878',
#        '$4.8678', '$365.9878', '$207.3878', '$853.9878', '$683.1878',
#        '$439.1878', '$609.9878', '$170.7878', '$134.18779999999998',
#        '$20.7278', '$975.9878', '$280.5878', '$45.1278', '$91.4878',
#        '$32.9278', '$14.6278', '$317.1878', '$231.7878', '$128.0878',
#        '$341.5878', '$103.6878', '$487.9878', '$1035.78',
#        '$31.192200000000003', '$19.4922', '$12.4722',
#        '$101.39220000000002', '$77.9922', '$62.3922', '$58.4922',
#        '$54.5922', '$38.9922', '$35.092200000000005',
#        '$155.99220000000003', '$10.1322', '$9.3522', '$179.3922',
#        '$140.3922', '$132.59220000000002', '$116.9922', '$85.7922',
#        '$70.1922', '$50.6922', '$46.7922', '$23.3922', '$15.5922',
#        '$7.0122', '$6.2322000000000015', '$27.2922', '$14.0322',
#        '$7.7922', '$5.4522', '$2.3322000000000003', '$350.9922',
#        '$171.59220000000005', '$265.1922', '$233.99220000000003',
#        '$194.99220000000003', '$148.1922', '$93.5922', '$272.9922',
#        '$124.7922', '$257.3922', '$42.8922', '$11.6922', '$311.9922',
#        '$14.8122', '$3.8922', '$167.6922', '$74.0922', '$28.0722',
#        '$18.7122', '$28.041000000000004', '$109.1922', '$3.1122',
#        '$21.8322', '$588.8922', '$378.2922', '$28.852200000000003',
#        '$616.1922000000002', '$13.252199999999998', '$467.9922',
#        '$701.9922', '$288.5922', '$187.1922', '$17.1522', '$121.38',
#        '$86.59800000000001', '$71.298', '$61.098', '$50.898', '$40.698',
#        '$35.598', '$192.78', '$25.398000000000003', '$12.138', '$213.18',
#        '$151.98', '$141.78', '$101.898', '$91.698', '$23.358', '$20.298',
#        '$18.258', '$7.0379999999999985', '$30.498', '$10.098',
#        '$6.0180000000000025', '$2.958', '$21.318', '$182.58', '$396.78',
#        '$284.58', '$264.18', '$81.498', '$304.98', '$96.798', '$417.18',
#        '$243.78', '$111.18', '$66.19800000000001', '$15.198', '$27.438',
#        '$254.898', '$131.58', '$45.798', '$4.998', '$355.98', '$202.98',
#        '$233.58', '$857.7180000000002', '$821.0898', '$528.258',
#        '$39.678', '$590.58', '$172.38', '$967.98', '$274.38',
#        '$129.55200000000002', '$86.352', '$81.55199999999998', '$67.152',
#        '$62.352', '$57.552', '$43.152', '$38.352', '$215.952', '$23.952',
#        '$12.432', '$239.952', '$177.55200000000005', '$158.352',
#        '$143.952', '$139.15200000000002', '$124.75200000000001',
#        '$110.352', '$95.952', '$76.752', '$52.752', '$19.152', '$12.912',
#        '$11.952', '$7.152', '$47.952', '$40.752', '$33.552', '$9.552',
#        '$6.192', '$3.3120000000000003', '$431.952', '$335.952',
#        '$311.952', '$167.952', '$119.952', '$383.952', '$115.152',
#        '$479.952', '$287.952', '$28.752', '$134.352', '$16.752',
#        '$91.152', '$71.952', '$191.952', '$163.15200000000004',
#        '$503.952', '$263.952', '$4.752', '$14.352', '$767.952', '$715.2',
#        '$719.952', '$153.55200000000005', '$955.2', '$21.552',
#        '$81.72779999999999', '$176.8878', '$10.9678',
#        '$82.94779999999999', '$37.8078', '$251.3078', '$165.9078',
#        '$115.88779999999998', '$69.5278', '$35.36779999999999',
#        '$92.7078', '$17.0678', '$43.9078', '$463.5878', '$47.5678',
#        '$152.4878', '$225.6878', '$140.2878', '$213.4878', '$68.3078',
#        '$104.9078', '$93.9278', '$974.78', '$164.6878', '$13.4078',
#        '$107.88', '$77.88', '$65.88', '$53.88', '$47.88', '$41.88',
#        '$36.0', '$30.0', '$167.88', '$32.4', '$24.0', '$12.0', '$203.88',
#        '$131.88', '$119.88', '$95.88', '$89.88', '$21.6', '$18.0',
#        '$15.6', '$6.0', '$27.6', '$8.4', '$4.8', '$2.4', '$323.88',
#        '$251.88', '$239.88', '$179.88', '$155.88', '$71.88', '$275.88',
#        '$29.88', '$23.88', '$15.48', '$359.88', '$10.8', '$83.88',
#        '$59.88', '$143.88', '$3.6', '$311.88', '$215.88', '$522.0',
#        '$499.2', '$321.12', '$539.88', '$102.0', '$839.88', '$146.339',
#        '$109.739', '$91.439', '$79.23899999999998', '$60.93899999999999',
#        '$48.739', '$42.639', '$231.739', '$30.439', '$15.799', '$243.939',
#        '$182.939', '$170.73899999999998', '$121.939', '$103.639',
#        '$85.339', '$73.139', '$36.539', '$24.339', '$21.899',
#        '$7.258999999999999', '$12.139', '$6.039', '$3.599', '$67.039',
#        '$219.539', '$487.939', '$341.539', '$329.339', '$268.339',
#        '$134.139', '$97.539', '$365.939', '$54.83900000000001',
#        '$280.539', '$158.539', '$18.239', '$32.879', '$195.139', '$4.819',
#        '$426.939', '$304.939', '$731.9390000000003', '$292.7390000000001',
#        '$1097.939', '$353.7390000000001', '$115.839',
#        '$207.33900000000003', '$45.75', '$23.1678', '$46.3478',
#        '$29.2678', '$475.7878', '$52.4478', '$451.3878', '$21.35',
#        '$25.6078', '$201.2878', '$136.62779999999998', '$118.986',
#        '$90.986', '$76.986', '$62.986', '$41.986', '$209.986',
#        '$36.385999999999996', '$25.186', '$13.985999999999999', '$11.186',
#        '$153.986', '$111.986', '$97.986', '$55.986', '$48.986', '$34.986',
#        '$27.986', '$22.386', '$20.986', '$18.186', '$14.686', '$12.586',
#        '$6.9860000000000015', '$9.786', '$2.786', '$39.18599999999999',
#        '$181.986', '$419.986', '$307.986', '$251.986', '$223.986',
#        '$200.186', '$104.986', '$349.986', '$139.986', '$69.986',
#        '$57.386', '$23.785999999999998', '$16.785999999999998', '$5.586',
#        '$83.986', '$15.386', '$398.986', '$195.986', '$167.986',
#        '$125.986', '$284.186', '$114.786', '$32.18599999999999',
#        '$29.386', '$363.986', '$4.186', '$713.9860000000001', '$686.252',
#        '$440.986', '$33.586', '$573.986', '$237.986', '$909.986',
#        '$265.986', '$64.6478', '$22.3138', '$31.7078', '$309.8678',
#        '$189.0878', '$16.104', '$256.1878', '$43.3954', '$89.0478',
#        '$15.2378', '$378.1878', '$101.2478', '$155.87', '$103.87',
#        '$90.87', '$77.87', '$64.87', '$58.37000000000001',
#        '$51.87000000000001', '$45.37000000000001', '$220.87', '$25.987',
#        '$12.987000000000002', '$259.87', '$181.87', '$142.87', '$129.87',
#        '$116.87', '$97.37', '$90.987', '$71.37', '$45.487', '$38.987',
#        '$29.887', '$28.587000000000003', '$25.87', '$22.087',
#        '$7.787000000000001', '$19.487000000000002', '$10.387', '$6.487',
#        '$3.12', '$233.87', '$454.87', '$389.87', '$324.87', '$168.87',
#        '$493.87', '$285.87', '$32.486999999999995', '$23.387',
#        '$15.587000000000002', '$38.87000000000001', '$84.37', '$207.87',
#        '$194.87', '$22.035', '$363.87', '$5.187', '$415.87', '$246.87',
#        '$16.887', '$605.735', '$579.735', '$371.735', '$28.535',
#        '$714.87', '$298.87', '$1104.87', '$337.87', '$127.7929',
#        '$92.2929', '$70.99289999999998', '$63.89289999999999', '$49.6929',
#        '$42.5929', '$212.9929', '$35.4929', '$28.3929',
#        '$14.192899999999998', '$269.7929', '$198.7929', '$177.4929',
#        '$120.6929', '$78.09289999999999', '$56.7929', '$24.8429',
#        '$21.2929', '$9.2229', '$7.0929', '$31.9429', '$17.7429',
#        '$3.5429', '$85.1929', '$425.9929', '$319.4929', '$283.9929',
#        '$248.4929', '$156.1929', '$141.9929', '$99.3929', '$354.9929',
#        '$262.6929', '$12.772899999999998', '$106.4929', '$11.3529',
#        '$16.322899999999994', '$191.6929', '$24.1329', '$22.365',
#        '$163.2929', '$4.2529', '$922.9929', '$709.9929', '$567.29',
#        '$638.9929', '$184.5929', '$113.5929', '$1064.9929', '$130.4971',
#        '$86.9971', '$81.19709999999998', '$63.7971', '$57.9971',
#        '$52.1971', '$43.4971', '$37.6971', '$202.9971', '$26.0971',
#        '$13.0471', '$12.4671', '$231.9971', '$173.9971', '$144.9971',
#        '$121.7971', '$115.9971', '$104.3971', '$89.8971', '$72.4971',
#        '$60.8971', '$23.197099999999995', '$20.2971', '$11.5971',
#        '$7.247099999999999', '$34.79709999999999', '$28.9971', '$17.3971',
#        '$10.1471', '$5.7971', '$2.8971', '$78.2971', '$75.3971',
#        '$46.3971', '$31.897099999999995', '$435.0', '$319.0', '$289.9971',
#        '$240.6971', '$197.1971', '$188.4971', '$159.4971', '$92.7971',
#        '$348.0', '$66.69709999999999', '$49.2971', '$40.5971',
#        '$110.1971', '$449.21', '$275.4971', '$107.2971', '$95.6971',
#        '$55.0971', '$464.0', '$153.6971', '$98.5971', '$69.5971',
#        '$179.7971', '$136.2971', '$478.4971', '$304.4971', '$345.1',
#        '$4.93', '$391.5', '$226.1971', '$101.4971', '$260.9971',
#        '$869.9999999999999', '$725.0', '$667.0', '$133.3971', '$113.0971',
#        '$1015.0', '$304.21', '$165.2971', '$118.8971', '$181.7678',
#        '$153.7078'], dtype=object)

# %% [markdown]
# ### Numerical Data Stored as Strings
#
# A common issue to check for at this stage is numeric columns that have accidentally been encoded as strings. For example, you should notice that the `list_price` column above is currently formatted as a string and contains a proceeding '$'. Remove this and convert the remaining number to a `float` so that you can later model this value. After all, your primary task is to generate model to predict the price.
#
# > Note: While the data spans a multitude of countries, assume for now that all prices have been standardized to USD.

# %%
# Your code here
df.list_price = [x.strip('$') for x in df.list_price]
df.list_price = df.list_price.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10512 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null float64
# num_reviews          9449 non-null float64
# play_star_rating     9321 non-null float64
# review_difficulty    9104 non-null object
# star_rating          9449 non-null float64
# val_star_rating      9301 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Detecting and Dealing With Null Values
#
# Next, it's time to check for null values. How to deal with the null values will be determined by the columns containing them, and how many null values exist in each.
#
# In the cell below, get a count of how many null values exist in each column in the DataFrame.

# %%
# Your code here
df.isna().sum()
# Out:
# prod_id                 0
# ages                    0
# piece_count             0
# set_name                0
# prod_desc             358
# prod_long_desc          0
# theme_name              0
# country                 0
# list_price              0
# num_reviews          1421
# play_star_rating     1549
# review_difficulty    1766
# star_rating          1421
# val_star_rating      1569
# dtype: int64

# %% [markdown]
# Now, get some descriptive statistics for each of the columns. You want to see where the minimum and maximum values lie.

# %%
# Your code here
df.prod_desc.unique()
# Out:
# array(['Catapult into action and take back the eggs from the Piggy Trike!',
#        'Launch a flying attack and rescue the eggs from the Piggy Plane!',
#        'Chase the piggy with lightning-fast Chuck and rescue the eggs!',
#        'Explore the architecture of the United States Capitol Building!',
#        'Recreate the Solomon R. Guggenheim Museum® with LEGO® Architecture!',
#        'Celebrate Shanghai with this LEGO® Architecture Skyline set!',
#        'Celebrate New York City with this LEGO® Architecture Skyline model!',
#        'Recreate Buckingham Palace with LEGO® Architecture!',
#        'Celebrate London with this LEGO® Architecture Skyline model!',
#        'Celebrate Chicago with this LEGO® Architecture Skyline model!',
#        'Experience the grandeur of the Arc de Triomphe!',
#        'Build your own LEGO® interpretation of the iconic Eiffel Tower!',
#        'Celebrate Sydney with this LEGO® Architecture Skyline model!',
#        'Bring your LEGO® creations to life!',
#        'Build a LEGO® BrickHeadz version of yourself!',
#        'Train a raptor with LEGO® BrickHeadz™ Owen and Blue!',
#        'Join Mr. Incredible and Frozone for LEGO® BrickHeadz™ crime-fighting fun!',
#        'Growl like a Wookiee with a LEGO® BrickHeadz™ construction character featuring Chewbacca!',
#        'Be a rogue with a LEGO® BrickHeadz™ construction character featuring Han Solo!',
#        'Save the universe with LEGO® BrickHeadz Iron Man MK50!',
#        'Feel the power of Infinity with LEGO® BrickHeadz Thanos!',
#        'Be a legendary outlaw with LEGO® BrickHeadz Star-Lord!',
#        'Master the skills of a green-skinned assassin with LEGO® BrickHeadz Gamora!',
#        'Join the Resistance with a LEGO® BrickHeadz construction character featuring Finn!',
#        "Say “I love you” with a LEGO® BrickHeadz™ Valentine's Bee!",
#        'Stand tall with LEGO® BrickHeadz Wonder Woman™!',
#        'Live life in the fast lane with LEGO® BrickHeadz The Flash™!',
#        'Summon the dark side with a LEGO® BrickHeadz construction character featuring Kylo Ren™!',
#        'Feel the Force with a LEGO® BrickHeadz construction character featuring Rey!',
#        'Dive in with LEGO® BrickHeadz Aquaman™!',
#        'Get an upgrade with LEGO® BrickHeadz Cyborg™',
#        'Travel back to the future with LEGO® BrickHeadz™ Marty McFly and Doc Brown!',
#        'Join the Justice League™ with LEGO® BrickHeadz™ Tactical Batman™ and Superman™!',
#        'Hop to it with a LEGO® BrickHeadz™ Easter Bunny!',
#        'Unleash your true ninja spirit with LEGO® BrickHeadz Lloyd!',
#        'Learn the way of the ninja with LEGO® BrickHeadz Master Wu!',
#        'Lead a LEGO® BrickHeadz ghost crew featuring Disney’s Captain Armando Salazar!',
#        'Lead the First Order with a LEGO® BrickHeadz construction character featuring Captain Phasma™',
#        'Celebrate THE LEGO® BATMAN MOVIE with a LEGO BrickHeadz Batman!',
#        'Stand your ground with your own LEGO® BrickHeadz Iron Man!',
#        'Treasure your own LEGO® BrickHeadz construction character featuring Disney’s Captain Jack Sparrow!',
#        'Have a smashing time with LEGO® BrickHeadz The Hulk!',
#        'Add some Disney fairytale romance with a LEGO® BrickHeadz construction character featuring Belle!',
#        'Bring a classic Disney tale to life with a LEGO® BrickHeadz construction character featuring Beast!',
#        'Show off the evil trickster with LEGO® BrickHeadz The Joker™!',
#        'Recruit your own elite agent with LEGO® BrickHeadz Black Widow!',
#        'Showcase the Boy Wonder with LEGO® BrickHeadz Robin™!',
#        'Channel Batgirl™ with your own LEGO® BrickHeadz version!',
#        'Keep the crooks from escaping with the gold bars!',
#        'Move heavy goods across LEGO® City with the Cargo Train!',
#        'Get around LEGO® City fast in the High-speed Passenger Train!',
#        'Haul in fresh supplies at the exploration site!',
#        'Sail the high seas and make a thrilling rescue!',
#        'Discover the secrets of the jungle with the LEGO® City explorers!',
#        'Throw the crooks back in jail after they break out!',
#        'Head to the LEGO® City mine and dig up some gold!',
#        'Jump into action and save the hot dog stand… and lunch!',
#        'Stop the crooks from breaking their partner out of jail!',
#        'Load up the truck and deliver the goods!',
#        'Protect the bank and stop the crooks!',
#        'Watch your step while you explore new things in the jungle!',
#        'Fly in and surprise the crooks at their hideout!',
#        'Perform a daring helicopter rescue before the shark gets too close!',
#        'Stop the crooks before they escape from the mobile jail!',
#        'Hop on, there’s so much to see with the LEGO® City bus!',
#        'Drive in the heavy driller and start digging the cave!',
#        'Pack your city with a bunch of new people!',
#        'Help Chase McCain and the police nab the crook!',
#        'Race to the rescue on land and sea!',
#        'Race after the crook and avoid the mountain rockslide!',
#        'Defend the mission and dodge a surprise in the jungle!',
#        'Call the Fire Response Unit for help!',
#        'Load up the Pickup & Caravan, it’s time for a vacation!',
#        'Haul in the helicopter to handle the heavy lifting!',
#        'Put out the burning oil barrel!',
#        'Jump the fire and give the crowd a thrilling show!',
#        'Order a pizza to go!', 'Get killer curves in your tracks!',
#        'Gear up for the big race!',
#        'Transport the mountain snowboarder to the hospital!',
#        'Load the freshly cut logs with the awesome Forest Tractor!',
#        'Catch the crook before he tows the safe away!',
#        'Speed after the crook on an exciting river chase!',
#        'Break up the rocks and discover the treasure inside!',
#        'Chase down the crook and recover the loot!',
#        'Fly in and save the stranded sailor before he floats away!',
#        'Fly into the jungle and explore the hidden temple!',
#        'Switch tracks – build a bigger, more exciting railway track.',
#        'Add roads to your LEGO® town!', 'Roads for your LEGO® layout!',
#        'Wow the crowds in the sleek Airshow Jet!',
#        'Cruise into the jungle and make a big discovery!',
#        'Grab your shovel and get to work!',
#        'Rescue the surfer and be a coast guard hero!',
#        'Arrest the crooks and recover the hidden loot!',
#        'Blow up the rock pile and discover gold!',
#        'Climb in the cockpit and set a new speed record!',
#        'Catch the crook before he escapes with the loot!',
#        'Explore the depths of the jungle and find something amazing!',
#        'Fill up your city with people!',
#        'Help out the volcano explorers and bring in the big equipment!',
#        'Get busy with some serious scientific work!',
#        'Save the lighthouse and rescue the keeper with the Fire Boat!',
#        'Stop the crooks from stealing their car again!',
#        'Keep the crook from escaping his boat ride to prison!',
#        'Fly in the exploration gear and fly out the crystals!',
#        'Bring out the heavy machinery to do exploring right!',
#        'Take the Ferry to your next adventure!',
#        'Rescue the sailor off the rocks just in time!',
#        'Celebrate 24 fun days with the LEGO® City Advent Calendar!',
#        'Load up the Cargo Plane and get ready to fly!',
#        'Head off-road and make the big discoveries!',
#        'Pack up the gear; it’s time to go camping!',
#        'Catch the crook before she gets away with the safe!',
#        'Stop the crooks before they empty the ATM!',
#        'Strap in and jump some ramps!',
#        'Start your engine and race through the dunes!',
#        'Explore the volcano and make an exciting discovery!',
#        "Help get LEGO® City's mail on the helicopter!",
#        'Save the dockworker and put out the blaze!',
#        'Chase down the crook with the ATV!',
#        'Create all kinds of buildings with LEGO® bricks, windows and doors!',
#        'Create your own LEGO® vehicles with LEGO Classic!',
#        'Bring along a world of creativity in your own LEGO® Creative Suitcase!',
#        'Get ideas, get creative and get building!',
#        'Get creative with classic LEGO® bricks in 29 different colors!',
#        'Add another useful piece to your LEGO® collection with this Gray Baseplate!',
#        'Create your own world on a Blue LEGO® Baseplate!',
#        'Add another useful piece to your LEGO® collection with this Bright Green Baseplate!',
#        'Unleash your imagination with the LEGO® Blue Creativity Box!',
#        'Unleash your imagination with the LEGO® Green Creativity Box!',
#        'Unleash your imagination with the LEGO® Red Creativity Box!',
#        'Unleash your imagination with the LEGO® Orange Creativity Box!',
#        'Everyone needs one!',
#        'Build whatever your heart desires with LEGO® bricks in 20 different bright colors!',
#        'Add another useful piece to your LEGO® collection with this Sand Baseplate!',
#        'Build and enjoy the delightful 3-in-1 Family Villa!',
#        'Get behind the wheel of the awesome 3-in-1 Turbo Track Racer!',
#        'Enjoy awesome activities at the 3-in-1 Modular Skate House!',
#        'Enjoy seaside fun with the 3-in-1 Sunshine Surfer Van set!',
#        'Hit the slopes with the 3-in-1 Modular Winter Vacation set!',
#        'Launch a satellite with the 3-in-1 Space Shuttle Explorer!',
#        'Enjoy eco-friendly adventures with the 3-in-1 Modern Home!',
#        'Play all day on a 3-in-1 Poolside Holiday!',
#        'Have fun with the cute 3-in-1 Robo Explorer!',
#        'Blast off from the start line in the 3-in-1 Rocket Rally Car!',
#        'Thrill the crowds with the 3-in-1 Daredevil Stunt Plane set!',
#        'Head into the wilds with the 3-in-1 Outback Adventures set!',
#        'Enjoy roaring adventures with the 3-in-1 Mighty Dinosaurs!',
#        'Create a world of scary 3-in-1 Mythical Creatures!',
#        'Take an open-top drive in the cool 3-in-1 Green Cruiser!',
#        'Perform cool maneuvers with the 3-in-1 Air Blazer!',
#        'Be an eye in the sky with the 3-in-1 Drone Explorer!',
#        'Enter the racing world with the 3-in-1 Extreme Engines set!',
#        'Get ready for the ultra-cool 3-in-1 Fast Car!',
#        'Take the 3-in-1 Sunset Street Bike for high-speed spin!',
#        'Meet the wildlife at the brightly lit Lighthouse Point!',
#        'Fly to warmer climes for 3-in-1 Island Adventures!',
#        'Enjoy summer adventures with the 3-in-1 Beach Hut!',
#        'Enjoy the beach life with the 3-in-1 Beachside Vacation!',
#        'Conquer ice and snow with the 3-in-1 Twin Spin Helicopter!',
#        'Take a flight in the cool 3-in-1 Propeller Plane!',
#        'Take the 3-in-1 Airshow Aces to town!', nan,
#        'Airlift vital supplies with the awesome 3-in-1 Cargo Heli!',
#        'Discover the architectural wonder of the Taj Mahal!',
#        'Discover a place where music is on the menu!',
#        'Head home for the holidays with the Winter Village Station!',
#        'Celebrate ten years of Modular Building with the Assembly Square!',
#        'Build the world’s best-known clock tower!',
#        "Build London's famous Tower Bridge!",
#        'Discover the fairground’s star attraction with the Carousel!',
#        'Experience the wonderful LEGO® Creator Ferris Wheel!',
#        'Make a safe deposit at the Brick Bank!',
#        'Have an unforgettable evening at the amazing Parisian Restaurant!',
#        "Discover hidden clues and surprises at the Detective's Office!",
#        'All aboard the London Bus!',
#        'Road trips will never be the same again with the iconic 1962 Volkswagen T1 Camper Van',
#        'Head for the beach with the VW Beetle!',
#        'Take this MINI Cooper for a nostalgic drive down memory lane!',
#        'Climb aboard the magical Winter Holiday Train!',
#        'Dare to enter The Joker™ Manor!',
#        'Unleash the Batmobile from The Flying Fox!',
#        "With LEGO® Dimensions™, you're gonna need a bigger imagination!",
#        'Launch a space mission from the Batcave!',
#        'Fight for the Mother Box with Batman’s Knightcrawler!',
#        'Dodge Harley Quinn’s cannonball attacks!',
#        'Power up for battle against the Lex Luthor™ Mech!',
#        'Pursue Reverse Flash™ and grab the Energy Infuser!',
#        'Party on with Superman™ and friends!',
#        'Join Batman™ in a comical food fight!',
#        'Swoop in with Batman™ and take on the Joker™!',
#        'Bring down Captain Boomerang™ with Batman’s Bat-Dune Buggy!',
#        'Protect the precious Mother Box from the evil Parademon™!',
#        'Help Superman™ bust out of the Kryptonite prison!',
#        'Train your skills and learn how to become a Super Hero!',
#        'Recover Batgirl’s ePad from the evil Kryptomite™!',
#        'Save the super hero café from the evil Kryptomites!',
#        'Rescue Krypto™ from Lashina’s clutches!',
#        "Drive the villains out from Batman's Batcave!",
#        'Rescue The Flash™ from Eclipso’s evil plans!',
#        'Bite back against Killer Croc™ with the Bat-Tank!',
#        'Help Batman™ rescue the farmer from Scarecrow™ and Killer Moth™!',
#        'Stop Lena Luthor™ from making evil little Kryptomites!',
#        'Help Batgirl™ nab Mad Harriet™ and recover the microchip!',
#        'Intercept the Kryptonite with the armored Batmobile!',
#        'Help Wonder Woman™ defeat the villainous Ares™!',
#        "Break out Robin™ from Ra's al Ghul's secret headquarters!",
#        'Zoom into orbit and recover Green Lantern’s lantern!',
#        'Keep the crystals from the evil Kryptomites!',
#        'Get set for a Batman™ v Superman™ rooftop duel!',
#        'Stage a Kryptonite clash with Superman™ and Bizarro™!',
#        'Fly Batman™ into battle against Killer Moth™!',
#        'Dive into battle against Doomsday™ with Wonder Woman™!',
#        'Get ready to save the day in the LEGO® DIMENSIONS™ multiverse with Starfire in the Teen Titans Go!™ Fun Pack!',
#        'Save the world before bedtime in the LEGO® DIMENSIONS™ multiverse with Buttercup™, the toughest fighter!',
#        'Sugar, spice and everything nice! Bring Townsville to life in the LEGO® DIMENSIONS™ multiverse with Blossom™ and Bubbles™!',
#        'It’s showtime! Bring Beetlejuice™ to life in the LEGO® DIMENSIONS™ multiverse for an eerie adventure!',
#        'Fight off villains with Raven and Beast Boy in the Teen Titans Go!™ Team Pack!',
#        'Get spooky with Abby Yates and the Ghostbusters™!',
#        'Fight crime with Batgirl™ and Robin™ in THE LEGO® BATMAN MOVIE!',
#        'Search for treasure while avoiding the Fratelli family in the Goonies™ Level Pack!',
#        'Hang by a thread with Ethan on a Mission: Impossible™ level!',
#        "Get devious with DC Comics' The Joker™ & Harley Quinn™!",
#        'Go retro with the LEGO® DIMENSIONS™ Midway Arcade™ Level Pack!',
#        'Continue your wizarding adventures in LEGO® DIMENSIONS™ with your very own Harry Potter™ Fun Pack featuring Hermione Granger.',
#        'Help stop crime in the LEGO® DIMENSIONS™ multiverse with LEGO® City’s Fun Pack',
#        'Set out on time-traveling adventures with Cyberman™ from Doctor Who!',
#        'Keep watch over the multiverse from the shadows with Gollum™ from The Lord of the Rings™!',
#        'Team up with LEGO® Chima’s™ Eris to outsmart the competition!',
#        'Welcome to the magical Disney Castle!',
#        'Discover the secrets of the Silent Mary!',
#        'Spend a day in the snow at Elsa’s Magical Ice Palace!',
#        'Dine and dance at the Dream Castle with Disney Cinderella.',
#        'Sail off to new adventures with Disney Ariel and Eric.',
#        'Set sail with Moana to restore the heart of Te Fiti!',
#        'Help Disney Aurora turn the spinning wheel in her Fairytale Castle!',
#        'Drive off in Cinderella’s beautiful horse-drawn carriage!',
#        'Roll up for a demolition derby at the Disney•Pixar Thunder Hollow Crazy 8 Race!',
#        'Explore the secrets of the sea with Ariel and Flounder.',
#        'Play in the snow with Anna and Elsa at the ice palace!',
#        'Fix Disney•Pixar’s Lightning McQueen for his next exciting race!',
#        'Smash the speed record with Disney•Pixar’s Lightning McQueen and Sheriff!',
#        'Visit Arendelle Market with Elsa and Olaf!',
#        'Get in training with Disney Mulan, ready for the challenge ahead!',
#        'Power on and win with Disney•Pixar’s Lightning McQueen!',
#        'Take a break at the junkyard with Disney•Pixar’s Mater and his video screen!',
#        'Decorate and customize your castle!',
#        'Create beautiful mini-doll outfits!',
#        'Pull in to Disney•Pixar’s Guido & Luigi’s Pit Stop for fun and games!',
#        'Help Disney•Pixar’s Cruz Ramirez become the fastest race car around!',
#        'Help Anna and Kristoff bring summer back to Arendelle!',
#        'Help Moana find the heart of Te Fiti and fulfill her destiny!',
#        'Host a grand ball for all the Palace Pets!',
#        'Take a break with Anna and her horse on their journey!',
#        'Win the show jumping prize with Petite!',
#        'Make a cake for Berry’s tea party!',
#        'Help Owen Grady get the escaped T. rex under control in Jurassic World!',
#        'See the baby dinosaurs at the Jurassic World Gentle Giants Petting Zoo!',
#        'Take the rocks down the track with the Deluxe Train Set!',
#        'Go Around the World on LEGO® DUPLO® adventures!',
#        'Enjoy a day of family fun at LEGO® DUPLO® Big Fair!',
#        'Enjoy a visit to the adventure farm and feed the animals!',
#        'Explore the Town Square for endless fun and play opportunities!',
#        'Get busy with a bulldozer, tipper truck and posable crane!',
#        'Develop creativity and fine motor skills with a playground theme!',
#        'Hop aboard My First Train Set for beginning builder fun!',
#        'Play out everyday scenes and routines in the Family House!',
#        'Build and run the store with Disney’s Minnie Mouse and Daisy Duck!',
#        'Turn the carousel for a day of fun at the fair!',
#        'Hang out with Lightning McQueen, Mack and Cruz Ramirez!',
#        'Spend a day at the beach with Mickey Mouse and friends!',
#        'Enjoy a delicious pizza at the LEGO® DUPLO® Pizzeria!',
#        'Help Batman™ use the Batwing to retrieve the stolen treasure back from The Penguin!',
#        'Race Lightning McQueen and Jackson Storm for the Piston Cup!',
#        'Build your own holiday season fun with Santa and his sleigh!',
#        'Help Spider-Man and Hulk fight Sandman at Avengers HQ!',
#        'Make an animal train with these fun and colorful models.',
#        'Help Rapunzel groom Maximus and play out life in the tower.',
#        'Take care of the ponies at the Farm Pony Stable!',
#        'Imagine and create with this great-value set of colorful bricks!',
#        'Learn to discover, build and count with the All-In-One Box of Fun!',
#        'Rush to save the burning building in the LEGO® DUPLO® Fire Truck!',
#        'Celebrate your birthday with Mickey and Minnie!',
#        'Test your aim at the LEGO® DUPLO® Shooting Gallery!',
#        'Turn the cone to make the carousel spin!',
#        'Head off on vacation at the LEGO® DUPLO® Airport!',
#        'Play and learn all day long at the LEGO® DUPLO® Preschool!',
#        'Introduce counting with this easy-to-build train!',
#        'Learn to build and create your own fleet of LEGO® DUPLO® vehicles!',
#        'Dig and shovel all day, then drive the rubble away!',
#        'Join in Mater’s video chat with Lightning McQueen!',
#        'Buy fresh fruit and vegetables from the market stall!',
#        'Enjoy a tea party with Belle and her extraordinary friends!',
#        'Explore different emotions with these buildable characters.',
#        'Help Disney’s Mickey Mouse get his roadster ready for the next race!',
#        'Play in the park and enjoy a fun birthday picnic!',
#        'Stop the crook and lock him in the police van!',
#        'Throw a LEGO® DUPLO® celebration with these buildable cakes!',
#        'Start creations here!',
#        'Play all day with the cute LEGO® DUPLO® Family Pets!',
#        'Learn to look after the little farm animals!',
#        'Learn about colors and pets with 3 fun puzzles!',
#        'Watch little bus drivers go places as they build and play!',
#        'Create, learn and play with the little ladybug!',
#        'Create racing role-play stories with the colorful car!',
#        "Lock up Green Goblin in Spider-Man's amazing Spider Truck!",
#        "Tune up the motorcycle in Spider-Man's workshop!",
#        'Combine the bricks to create your own buildings and stories!',
#        'Fly through the Jungle and make some animal friends!',
#        'Dance with Cinderella and the Prince in the Magical Castle!',
#        'Help toys feel better in Doc McStuffins™’ Backyard Clinic!',
#        'Join Sofia the First and ride along in her magical carriage!',
#        'Get creative with LEGO® DUPLO® throughout the year!',
#        "The Doc is in…and now she's caring for pets too!",
#        'Head off on your holidays with the LEGO® DUPLO® Airport!',
#        'Learn about daily routines with this easy-to-build set!',
#        'Learn to match pairs with LEGO® DUPLO® My First Truck!',
#        'Learn about colors and fruits with this easy-to-build set!',
#        'Look after baby animals from all around the world!',
#        'Safety check the LEGO® DUPLO® Little Plane, then head for the skies!',
#        'Turn this colorful caterpillar into a beautiful butterfly!',
#        'Watch little builders take flight with My First Plane!',
#        'Watch budding builders take flight with this colorful parrot!',
#        'Watch little bakers serve up cute LEGO® DUPLO® cakes!',
#        'Stop the Goblin King’s evil plan and rescue Emily Jones’ sister!',
#        'Rescue the captured Guardian Earth Fox from Noctura’s tower!',
#        'Heal the baby dragon and transform a goblin from bad to good!',
#        'Join forces with Aira and Lumia to protect the Wind Dragon!',
#        'Search for crystals in the cave with the evil Goblin King!',
#        'Free the Guardian Fire Lion from the evil shadow bats’ chain!',
#        'Help Naida defend the Guardian Water Turtle from the shadow bat!',
#        'Escape the carnivorous plants with Azari and Firebolt!',
#        'Help Emily Jones find the lost diary page and outwit the shadow bat!',
#        'Explore the secret Goblin Village without getting caught!',
#        'Protect the crystals from the goblin thief!',
#        'Protect Sophie Jones from being captured in Elvendale!',
#        'Look after the sick and injured people of Heartlake City!',
#        'Make cakes ready for a party at Stephanie’s House!',
#        'Jump aboard the luxury Sunshine Catamaran with friends!',
#        'Plot mission after mission together at the Friendship House!',
#        'Get into winter sports with friends at the snow resort!',
#        'Set up camp with Mia’s luxury camper van!',
#        'Enjoy swimming in the sunshine at the Heartlake Summer Pool!',
#        'Show off your sporting prowess at the Sports Arena!',
#        'Chill out with frozen yogurt at Heartlake’s coolest hangout!',
#        'Stay cozy and warm in the beautiful log cabin!',
#        'Have fun playing at Heartlake City Playground with Mia and Sienna!',
#        'Get inspired with Emma at her favorite Art Café!',
#        'Climb up to the tree house and help Mia settle in!',
#        'Glide across the ice and show off your skills!',
#        'Cruise in style to the hottest beach party in town!',
#        'Enjoy pizza with friends at Heartlake’s Italian restaurant!',
#        'Keep warm with delicious hot chocolate from the van!',
#        'Put on a show in the park with Andrea and Pepper!',
#        'Drive to the rescue in Heartlake City with Olivia and Zobo.',
#        'Spend a day painting in the park with Emma and Chico!',
#        'Pick up some tasty organic goodies from Mia and Twister!',
#        'Get ready for a day of watersports action at the Surf Shop!',
#        'Score goal after goal with Stephanie and Dash!',
#        'Work on Olivia’s latest invention in her hi-tech bedroom!',
#        'Join Emma and her cat for a fun party in the park!',
#        'Stephanie is always on the go… even at home in her bedroom!',
#        'Explore Mia’s bedroom and discover her personality!',
#        'Keep things safe inside this cute buildable hedgehog!',
#        "Look after Heartlake's coolest canines!",
#        'Head to the Heartlake Party Shop for all your celebration supplies!',
#        'Train for the big dog show with Sky the puppy!',
#        'Learn to sing, dance and play with friends in Heartlake City!',
#        'Train for the next big horse show at the Heartlake Riding Club!',
#        'Stay fit and healthy at the Heartlake Sports Center!',
#        'Count down to Christmas with LEGO® Friends!',
#        'Help Mia’s cute pups win the Championship!',
#        'Drive the van to send special gifts all around Heartlake City!',
#        'Arrive at the dog show in style with a puppy limo!',
#        'Hop on the scooter and zoom off to catch some waves!',
#        'Sing your heart out with Andrea and her pet parrot!',
#        "Pamper Emma's cute pet foal at the Foal's Washing Station!",
#        'Get puppy Lara ready for her big dog show debut!',
#        'Get ready to bust some ghosts at the Firehouse Headquarters!',
#        'Speed after Mayhem with the LEGO® Ghostbusters™ Ecto-1 & 2 vehicles!',
#        'Designed by fan creator, Jake Sadovich, Idaho, USA.',
#        'Reimagine Disney’s TRON: Legacy movie scenes with LEGO® bricks!',
#        'Prepare for the ultimate fishing trip!',
#        'Build the first rocket to land people on the Moon!',
#        'What time is it? It’s LEGO® Adventure Time™!',
#        'Build, play and learn from inspiring women of NASA!',
#        'Add quirky vehicle style to your shelf or desk!',
#        'Defend the baby dinosaur and eggs from the angry T. rex!',
#        'Capture Brick before she knocks the house down!',
#        'Rescue the Raptor before the volcano erupts!',
#        'Defend Metroville’s bank vault from the Underminer!',
#        'Escape Jurassic Island before the Pteranadon attacks!',
#        'Grab the helicopter and help Elastigirl save the city!',
#        'Race with Disney•Pixar’s Lightning McQueen for the trophy!',
#        'Tear it down and build it again!',
#        'It’s feeding time down at the animal farm!',
#        'Swing into action with Spider-Man and catch the Scorpion!',
#        'Help Kai and Lloyd save NINJAGO® City from Great White!',
#        'Help the firefighters battle the blaze!',
#        'Race against Chopper Maroon for the treasure map!',
#        'Help Snow White choose a pie to bake for her animal friends!',
#        'Battle Mr. Freeze™ with Batman™ and his Batboat on the Gotham City Sea!',
#        'Have fun at the seaside with Stephanie and Andrea!',
#        'Protect the Spider-Man™ Hideout against an aerial assault from Green Goblin!',
#        'Discover the Lost Temple and help Lloyd win the Sword of Fire!',
#        'Catch the crook before he gets away!',
#        'Help Kai protect the golden snake staff and stop Lasha!',
#        'Plan a day of riding with friends!',
#        'Ride the waves with Ariel and Flounder as she explores new worlds in her dolphin carriage!',
#        'Catch the thief and protect the ATM with the Police Helicopter Chase!',
#        'Rescue Maisie from the Indoraptor at Lockwood Estate!',
#        'Escape from the rampaging Carnotaurus!',
#        'Help Zia round up the T. rex and save the day!',
#        'Play a game of hide and seek with the Velociraptor!',
#        'Defend the outpost from the terrifying Dilophosaurus!',
#        'Rescue Blue the Velociraptor from Wheatley and the pilot!',
#        'Stage a security breach with a dinosaur lab breakout!',
#        'Chase the Pteranodon and rescue it from danger!',
#        'Create and show off the mighty Hulkbuster!',
#        'Stop Cull Obsidian and Ebony Maw stealing the Infinity Stone!',
#        'Battle Thanos for the Infinity Gauntlet with the Avengers!',
#        'Repel Corvus Glaive’s thresher attack on the Wakandan wall!',
#        'Bash the ball-shooting gun turret with the Hulkbuster!',
#        'Find Thor’s ultimate weapon!',
#        'Defend Wakanda from attack with the Avengers!',
#        'Battle for freedom in the arena with Hulk and Thor!',
#        'Get ready for a clash of the Hulks!',
#        'Fight for the future of Asgard!',
#        'Intercept The Shocker and take down the Vulture!',
#        'Capture Killmonger with Nakia’s awesome Royal Talon Fighter!',
#        'Send in Iron Man to rescue Agent Coulson from Detroit Steel!',
#        'Battle Killmonger for the precious vibranium with Black Panther!',
#        'Foil the masked robbers’ bank raid!',
#        "Retrieve Captain America's shield from evil Super-Adaptoid!",
#        'Match Thor against Loki in an epic Mighty Micros clash!',
#        'Help Star-Lord grab the stolen mixtape from Nebula!',
#        'Jet into a fun-packed Scarlet Spider vs. Sandman clash!',
#        'Begin a battle of the bugs with Spider-Man and Scorpion!',
#        'Team up to take on Ayesha and save the galaxy!',
#        'Jump to the rescue and control the blaze with the Avengers and Spider-Man!',
#        'Banish the portal beast from Doctor Strange’s Sanctum Sanctorum!',
#        'Team up with Mantis and Rocket and fight back against Taserface!',
#        'Take down the Ultron jet with super-jumping Iron Man!',
#        'Thrust Iron Man into battle against evil Thanos!',
#        'Take a swipe at Magneto with the mighty Wolverine!',
#        'Create and command robots that do what you want with LEGO® MINDSTORMS® EV3!',
#        'Experience the Mountain Cave!',
#        'Unlock the treasures of the Ocean Monument!',
#        'Build and defend the awesome Waterfall Base!',
#        'Expand your LEGO® Minecraft™ universe!',
#        'Create a flourishing Farm Cottage!',
#        'Board the minecart and journey through the Nether Portal!',
#        'Set up base at the Polar Igloo!', 'Ride The Nether Railway!',
#        'Enjoy Minecraft™ farming adventures with the Chicken Coop!',
#        'Enter the Zombie Cave at your peril!',
#        'Spring a surprise attack with The Iron Golem!',
#        'Discover The Mushroom Island!',
#        'Battle the hostile mobs in the Nether Fight!',
#        'Grow and trade your crops at the Melon Farm!',
#        'Battle the hostile mobs at The Nether Fortress!',
#        'Build and defend The Jungle Tree House!',
#        'Venture into the stronghold and activate the End portal!',
#        'Prepare for battle at The Desert Outpost!',
#        'Prepare to battle the wither!',
#        'Enter the zombie-spawning dungeon at your peril!',
#        'Get the party started with LEGO® Minifigures!',
#        'Discover new heroes and villains in LEGO® Minifigures—THE LEGO BATMAN MOVIE Series 2.',
#        'Bring the NINJAGO® world to life with LEGO® Minifigures!',
#        'Collect the LEGO® Minifigures, Series 17—A story in every bag!',
#        'Stand your ground and save the realm with the 2-in-1 Knighton Castle!',
#        "Deploy Axl's Rolling Arsenal for the biggest battles!",
#        'Drop in for a surprise attack with Aaron’s X-bow!',
#        'Suit up for a Tech Wizard Showdown with Clay’s 3-in-1 mech!',
#        'Jet off with Macy for a Berserker Bomber battle!',
#        'Double the action with the 2-in-1 Twinfector!',
#        'Wipe out the tech infection with Lance’s Hover Jouster!',
#        'Protect Robot Hoodlum from The Bedrock Monster!',
#        'Watch Axl become unstoppable on the battlefield!',
#        'Stop the Stone stomper with the King’s Guard battle vehicle!',
#        'Roll into action with the NEXO KNIGHTS™ 2-in-1 battle castle!',
#        'Help the heroic knights rescue Ava from Jestro’s head-shaped HQ!',
#        "Protect the spell book from Burnzie in Axl's Tower Carrier!",
#        'Run rings around the Krakenbeast with Aaron’s 3-in-1 Rock Climber!',
#        'Keep trouble at bay with Axl’s 3-in-1 Rumble Maker!',
#        'Tower over the enemy with the monstrous Siege Machine of Doom!',
#        'Charge Lance into battle against the gargoyles!',
#        'Charge Axl into battle against the three fearsome brothers!',
#        'Rescue the queen from Ruina’s Lock & Roller!',
#        'Hunt the Rogul with Lance’s four-in-one Twin Jouster!',
#        'Smash Aaron Fox out of the way and capture the Book of Chaos!',
#        'Engage the Stone stomper with Macy’s Bot Drop Dragon!',
#        'Suit up with Clay and turn the Stone monsters to dust!',
#        'Send Lance speeding after the Stone monsters!',
#        'Grab a battle suit and help Aaron defend Knighton!',
#        'Hammer the enemy into defeat with Ultimate Flama!',
#        'Soar into battle with Ultimate Lance and his jet wings!',
#        'Unleash mighty Macy and send the Stone monsters running!',
#        "Knock out enemies with Ultimate Axl's gigantic fists!",
#        'Fire up Ultimate General Magmar to defeat the opponents!',
#        "Grow Jestro's army with these hot-headed Lava monsters!",
#        'Collect and combine the NEXO Powers to defeat Monstrox!',
#        'Join the ninja aboard Wu’s flying ship!',
#        'Live the life of a ninja in NINJAGO® City!',
#        'Evade the traps inside the Temple!',
#        'Turn sound into a weapon with Cole’s Quake Mech!',
#        'Defend NINJAGO® City from Garmadon Shark Mech attack!',
#        'Take on the shark army with Zane’s Ice Tank!',
#        'Explore the mysterious Temple of Resurrection!',
#        'Put the heat on the shark army with Kai’s Fire Mech!',
#        'Defend NINJAGO® City against Garma Mecha Man!',
#        'Speed to the rescue with Jay’s Lightning Jet!',
#        'Get weaponized for a dynamic Killow vs. Samurai X duel!',
#        'Get all fired up at Garmadon’s Volcano Lair!',
#        'Take on Garmadon with the Green Ninja Mech Dragon!',
#        'Attack the Sons of Garmadon underground dojo in Spinjitzu style!',
#        'Shoot on the go with Lloyd’s Ninja Nightcrawler!',
#        'Stage a high-speed bike showdown!',
#        'Smash the shark army out of the water with the Water Strider!',
#        'Battle against evil Jungle Garmadon on the jungle bridge!',
#        'Protect NINJAGO® City from flying Manta Ray Bomber attack!',
#        'Take on the tentacular Flying Jelly Sub with Jay!',
#        'Pursue Luke Cunningham with Kai’s Katana V11!',
#        'Stop a Piranha Attack with Kai and Misako!',
#        'Stop a crime in the NINJAGO® City street market!',
#        'Achieve Spinjitzu greatness with the Green Ninja!',
#        'Master Spinjitzu with the Red Ninja!',
#        'Create brilliant Spinjitzu tricks with the Blue Ninja!',
#        'Master the art of Spinjitzu with the Black Ninja!',
#        'Practice your Spinjitzu skills with Kai and Zane!',
#        'Build, rip and spin into action with Nya!',
#        'Create the coolest Spinjitzu tricks with the Ice Ninja!',
#        'Launch a surprise attack on the sky pirates’ awesome HQ!',
#        'Match the Salvage M.E.C. vs. the Skulkin mech in a bounty-hunting duel!',
#        'Watch out for the mighty egg-launching Vermillion Invader!',
#        "Glide across and above the swamp with Destiny's Shadow!",
#        'Fly high with Zane to battle Doubloon’s mighty Raid Zeppelin!',
#        'Take on Flintlocke’s Sky Shark with Ninja Lloyd!',
#        'Battle the Vermillion to win the Fast Forward Time Blade!',
#        'Build, display and race iconic Ferrari race cars!',
#        'Stage a historic Porsche race!',
#        'Build, display and race the 1968 Ford Mustang Fastback!',
#        'Team up with Ferrari “Scuderia Corsa” and triumph!',
#        'Drive the Fiesta M-Sport WRC to victory!',
#        'Play every role of a top motor racing team on race day!',
#        'Race your friends to win a 24-hour race!',
#        'Race to win a 24-hour race with the Porsche 919 Hybrid!',
#        'Customize the awesome AMG GT3 to race!',
#        'Design, build and race an incredible McLaren supercar!',
#        'Speed into race action with the awesome Scuderia Ferrari SF16-H!',
#        'Build and drive the ultimate hyper car!',
#        'Break records in this American dream car!',
#        'Refuel and race for victory!',
#        'Jump to lightspeed in the Millennium Falcon!',
#        'Evade the mighty Imperial TIE Fighter!',
#        'Go on the hunt with Moloch!',
#        'Train with Luke at Yoda’s Dagobah hideout!',
#        'Escape to safety with Han Solo’s Landspeeder!',
#        'Own a true Sith Lord with Darth Maul!',
#        'Stomp into action with the Range Trooper!',
#        'Battle the bad guys with Han Solo!',
#        'Take on the Separatists with the Jedi and Clone Troopers!',
#        'Patrol the Empire and enforce the rule of law!',
#        'Win the battle for the Empire with the awesome Death Star!',
#        'Lift off for bounty-hunting adventures in the Slave I!',
#        'Command the fleet with the awesome First Order Star Destroyer!',
#        'Stride into battle with the First Order Heavy Assault Walker!',
#        'Set out on heroic raids with the Resistance Bomber!',
#        'Play with and display your own brick-built BB-8!',
#        'Transport Director Krennic in his armor-plated shuttle!',
#        'Go head to head with the Empire aboard The Arrowhead!',
#        'Join the battle at the Resistance base!',
#        'Speed into action with Kylo Ren’s TIE Fighter!',
#        "Go on daring missions with Poe's X-Wing Fighter™!",
#        'Battle the Empire with the amazing Rebel U-Wing Fighter!',
#        'Escape from Bala-Tik and the dreaded Rathtars!',
#        'Search out the Freemakers with Tracker I!',
#        'Launch daring raids with the iconic Y-Wing Starfighter!',
#        'Set out on speeder bike missions with the Scout Trooper!',
#        'Escape Jakku in the powerful Quadjumper!',
#        'Stomp into battle with the First Order Heavy Scout Walker!',
#        'Stop by at Tatooine’s Mos Eisley Cantina!',
#        'Seize control of the First Order AT-ST!',
#        'Lead the charge with Chewbacca!',
#        'Learn the Jedi way at the Ahch-To Island mountainside hut!',
#        'Speed into action with the Sandspeeder!',
#        'Avoid the deadly Sarlacc pit!',
#        'Chase down the Jedi with General Grievous’ Combat Speeder!',
#        'Jettison to safety in the Resistance Transport Pod!',
#        'Bring Darth Vader to life at the medical bay!',
#        'Journey to the stars aboard Yoda’s starship!',
#        'Pack a punch with the Republic Fighter Tank!',
#        'Battle it out at the generator core!',
#        'Protect the First Order with the Elite Praetorian Guard!',
#        'Go on the hunt for Resistance forces with the fierce Kylo Ren™!',
#        'Join the battle with the 2-in-1 Stormtrooper Commander!',
#        'Feel the Force with Rey!',
#        'Intercept Kylo Ren in a deep space microfighter duel!',
#        'Pit First Order against Resistance in a micro planetside battle!',
#        'Fly into action with the Elite TIE Fighter Pilot!',
#        'Keep the Jawas busy on desert planet Tatooine!',
#        'Advance on the Resistance with the First Order Specialists Battle Pack!',
#        'Go bounty hunting with the super-fast speeder bike!',
#        'Send in reinforcements with the First Order Transport Speeder!',
#        'Play at micro lightspeed with the Millennium Falcon!',
#        'Take on the Resistance in a micro-scale TIE Fighter!',
#        'Enter miniature battle with the amazing U-Wing Microfighter!',
#        'Engage the Rebels with the tough TIE Striker Microfighter!',
#        'Build the ultimate LEGO® Snowspeeder!',
#        'Play at warp speed with Obi-Wan’s Jedi Starfighter With Hyperdrive!',
#        'Join Darth Vader and battle to victory!',
#        'Join the hunt with Boba Fett!',
#        'Go in search of Ben Kenobi in Luke’s Landspeeder!',
#        'Collect the ultimate long-range Rebel starfighter!',
#        'Travel the LEGO® galaxy in the ultimate Millennium Falcon!',
#        'Blast into battle with Rebel soldier Jyn Erso!',
#        'Jump into action with warrior monk Chirrut Îmwe!',
#        'Blast the enemy with tough Baze Malbus!',
#        'Track down those Rebels!',
#        'Presenting the Ultimate Collector Series TIE Fighter – the iconic Imperial starfighter!',
#        'Enter the battle with Kylo Ren’s Command Shuttle™!',
#        'Join the battle against the rebels!',
#        'Defeat Kylo Ren at the forest castle!',
#        'Uncover the Death Star plans at the beach bunker!',
#        'Join StarScavenger on dangerous salvage missions!',
#        "Stop the thief at Unkar Plutt's market stall!",
#        'Launch into the holidays with the LEGO® Star Wars Advent Calendar!',
#        'Join the Rebel battle aboard The Phantom!',
#        'Feel the power of the dark side with posable Darth Vader™!',
#        'Go behind enemy lines with K-2SO!',
#        'Command the troops with Captain Phasma™!',
#        'Use the Force to battle the Separatists with posable Obi-Wan Kenobi™!',
#        'Enforce Imperial rule with the Empire’s elite Death Trooper!',
#        "Speed into action on Rey's Speeder!™",
#        'Patrol the Scarif coastline with the armored Stormtrooper!',
#        'Practice your warrior skills with Finn!',
#        'Battle the Jedi with posable Jango Fett!™',
#        'Prepare for battle against the Resistance!',
#        'Patrol and defend Rebel territory!',
#        'Speed into battle against the First Order forces!',
#        'Blast the Resistance with the powerful turbolaser!',
#        'Shoot for the stars with the Y-Wing Microfighter!',
#        'Blast off on miniature X-Wing Fighter adventures!',
#        'Go on the hunt for microfighter rebels!',
#        'Fly in style with Krennic’s miniature Imperial Shuttle!',
#        'Speed across distant planets in the micro First Order Snowspeeder™!',
#        'Harness the power of the mighty 6x6 All Terrain Tow Truck!',
#        'Discover the iconic Porsche 911 GT3 RS!',
#        'Experience the huge Bucket Wheel Excavator!',
#        'Discover innovative design with the Mack Anthem truck and trailer!',
#        'Traverse uncharted territory with the Extreme Adventure!',
#        'Prepare for vertical takeoffs and landings with the Air Race Jet!',
#        'Discover new horizons with the Ocean Explorer!',
#        'Push the limits with the awesome LEGO® Technic Rally Car!',
#        'Travel over the toughest terrain with the RC Tracked Racer!',
#        'Mobilize the Airport Rescue Vehicle!',
#        'Transport supplies over land and sea with the all-terrain Hovercraft!',
#        'Experience the BMW R 1200 GS Adventure!',
#        'Grab, lift, load and deliver at the Container Yard!',
#        'Explore iconic vehicle design with the First Responder!',
#        'Put the wind in your sails with this amazing Racing Yacht!',
#        'Call in the Roadwork Crew!',
#        'Motorize your LEGO® Technic creations with the Power Functions Motor Set!',
#        'Get ready for high-speed action and impacts with the WHACK!',
#        'Fly off the ramp at high speed with the super-fast Stunt Truck!',
#        'Get ready for high-speed action and impacts with the BASH!',
#        'Take to the skies with the Ultralight Helicopter!',
#        'Hit the ramp at high speed with the awesome Stunt Bike!',
#        'Call in the powerful Dozer Compactor!',
#        'Collect and transport heavy cargo with the Hook Loader!',
#        'Harness the awesome power of the CLAAS XERION 5000 TRAC VC',
#        'Airlift massive loads with the Heavy Lift Helicopter!',
#        'Scream around the circuit in the lightning-fast LEGO® Technic 24 Hours Race Car!',
#        'Operate the powerful Volvo EW160E!',
#        'Take on mountainous terrain with the LEGO® Technic Formula Off-Roader!',
#        'Call in the powerful Mine Loader!',
#        'Take to the open road with the LEGO® Technic Street Motorcycle!',
#        'Utilize the power and reach of the awesome Telehandler!',
#        'Clear the ground with the LEGO® Technic Compact Track Loader!',
#        'Smash land speed records with the LEGO® Technic Record Breaker!',
#        'Thunder over the ocean with the Hydroplane Racer!',
#        'Reach dizzying heights with the awesome LEGO® Technic Cherry Picker!',
#        'Thrill the crowds with the Display Team Jet!',
#        'Break into Arkham Asylum with Batman™!',
#        'Divide the 4-in-1 Ultimate Batmobile and conquer the Super-Villains!',
#        'Protect the Batcave from The Penguin’s invasion!',
#        'Patrol the sky above Gotham City in The Batwing!',
#        'Pursue Man-Bat™ and the Kabuki Twins™ in the Batmobile with three driving modes!',
#        'Team up with Batgirl™ to stop The Joker’s Notorious Lowrider!',
#        'Protect Gotham City from Bane’s toxic attacks!',
#        'Put the heat on The Penguin™ Arctic Roller with Batman™!',
#        'Battle with Batman™ against The Riddler™ and his allies!',
#        'Help Batman™ to stop Scarecrow™ delivering a special scare pizza!',
#        'Protect the power plant from Mr. Freeze’s ice attack!',
#        'Power into the sky to stop Scarecrow’s fear gas attacks!',
#        'Help Batman™ stop The Joker™ escaping!',
#        'Display THE LEGO® BATMAN MOVIE minifigures!',
#        'Save the day with Batman™ and The Scuttler!',
#        'Speed after Killer Croc’s Tail-Gator on Batman’s Batski!',
#        'Don’t get on the wrong side of the Two-Face™ Excavator!',
#        'Duel against the mighty Clayface™ with Batman™!',
#        'Stop Catwoman™ escaping with the diamonds!',
#        'Imagine and create with LEGO® Classic bricks!',
#        'Create your ideas with LEGO® Classic bricks!',
#        'Create a world in motion with Bricks on a Roll!',
#        'Head for sunnier climes with the Vacation Getaways set!',
#        'Enjoy the holiday season with the Winter Toy Shop!',
#        'Fight ghosts with the LEGO® DIMENSIONS™ The Ghostbusters™ Level Pack!',
#        'Help Finn battle foes through an Adventure Time™ level!',
#        'Bring the Wizarding World to life with Harry and Voldemort!',
#        'Explore the Land of Ooo with Jake and Lumpy Space Princess!',
#        'Fight crime in the night with the bold and brave Excalibur Batman™!',
#        'Conquer the bad guys with action hero B.A. Baracus!',
#        'Become one with Spinjitzu Master Sensei Wu!',
#        'Dig your way through the multiverse as DC Comics™ villain, Bane™!',
#        'Carry on your crime-fighting adventure with Michael Knight and K.I.T.T.!',
#        'Imagine and create with this big box of colorful bricks!',
#        'Develop creativity and building skills with a selection of basic bricks!',
#        "Your robot's fingers!",
#        'Join the Ninja at the beautiful Temple of Airjitzu!',
#        'Prepare the A-wing for action!',
#        'Perfect your Spinjitzu skills with LEGO® NINJAGO™ Zane, the Ninja of Ice!',
#        'Puzzle through LEGO® DIMENSIONS™ Portal® 2 with Chell!',
#        'Unleash magical powers with the Wicked Witch™ of the West from The Wizard of Oz™!'],
#       dtype=object)

# %%
print(df.num_reviews.max())
print(df.num_reviews.min())
df.num_reviews.unique()
# Out:
# 367.0
# 1.0
# array([  2.,  11.,  23.,  14.,   7.,  37.,  24.,  53.,  63.,  13.,   1.,
#          3.,   5.,  nan,   4.,   6.,   8.,   9.,  10.,  12.,  35.,  45.,
#         16.,  89.,  47.,  85.,  40.,  30.,  46., 180.,  27.,  15.,  43.,
#         62.,  51.,  99.,  64., 228.,  91., 115., 202., 177., 337.,  66.,
#        134.,  77.,  19.,  18.,  32., 171.,  52.,  22.,  17., 130.,  83.,
#         79., 367.,  33.,  25.,  38.,  26.,  88.,  29.,  21.,  28.,  84.,
#        201.,  31.,  39.,  71.,  56.,  86., 197.,  36.,  94.,  67.,  70.,
#        143.,  75.,  57.,  20., 142.,  61.])

# %%
print(df.play_star_rating.max())
print(df.play_star_rating.min())
df.play_star_rating.unique()
# Out:
# 5.0
# 1.0
# array([4. , 4.3, 3.6, 3.2, 3.7, 4.4, 4.1, 4.2, 3.8, 4.7, 3. , 5. , 2. ,
#        nan, 4.6, 2.7, 4.5, 1. , 3.5, 3.3, 3.9, 4.8, 2.9, 3.4, 4.9, 2.5,
#        2.2, 2.3, 2.8, 3.1, 2.1])

# %%
df.review_difficulty.value_counts()
df.review_difficulty.unique()
# Out:
# array(['Average', 'Easy', 'Challenging', 'Very Easy', nan,
#        'Very Challenging'], dtype=object)

# %%
print(df.star_rating.max())
print(df.star_rating.min())
df.star_rating.unique()
# Out:
# 5.0
# 1.8
# array([4.5, 5. , 4.3, 4.6, 4.9, 4.2, 4.7, 4.8, 4.4, 3.4, 3. , 4. , nan,
#        3.7, 3.3, 4.1, 3.9, 2.5, 3.8, 3.5, 3.6, 3.2, 2.6, 2.2, 2.7, 2.8,
#        1.8, 2.9])

# %%
print(df.val_star_rating.max())
print(df.val_star_rating.min())
df.val_star_rating.unique()
# Out:
# 5.0
# 1.0
# array([4. , 4.1, 4.3, 4.4, 4.5, 3.6, 4.2, 3.5, 4.8, 5. , nan, 4.7, 3. ,
#        4.6, 4.9, 3.8, 3.3, 2.5, 2.7, 2.2, 2.3, 2.8, 2. , 2.9, 3.2, 3.9,
#        3.4, 2.6, 3.7, 1. , 1.8, 2.4, 1.9, 3.1])

# %% [markdown]
# Now that you have a bit more of a understanding of each of these features you can make an informed decision about the best strategy for dealing with the various null values.
#
# Some common strategies for filling null values include:
# * Using the mean of the feature
# * Using the median of the feature
# * Inserting a random value from a normal distribution with the mean and std of the feature
# * Binning
#
# Given that most of the features with null values concern user reviews of the lego set, it is reasonable to wonder whether there is strong correlation between these features in the first place. Before proceeding, take a minute to investigate this hypothesis.

# %%
# Investigate whether multicollinearity exists between the review features 
# (num_reviews, play_star_rating, star_rating, val_star_rating)
df.corr()
# Out:
#                    prod_id  piece_count  list_price  num_reviews  \
# prod_id           1.000000     0.221692    0.394525    -0.044658
# piece_count       0.221692     1.000000    0.865094     0.542208
# list_price        0.394525     0.865094    1.000000     0.437724
# num_reviews      -0.044658     0.542208    0.437724     1.000000
# play_star_rating -0.008234    -0.007952   -0.000685    -0.060884
# star_rating      -0.062264     0.067610   -0.006497     0.004541
# val_star_rating  -0.083703     0.067296   -0.055899     0.026664
#
#                   play_star_rating  star_rating  val_star_rating
# prod_id                  -0.008234    -0.062264        -0.083703
# piece_count              -0.007952     0.067610         0.067296
# list_price               -0.000685    -0.006497        -0.055899
# num_reviews              -0.060884     0.004541         0.026664
# play_star_rating          1.000000     0.619246         0.484341
# star_rating               0.619246     1.000000         0.731538
# val_star_rating           0.484341     0.731538         1.000000

# %% [markdown]
# Note that there is substantial correlation between the `play_star_rating`, `star_rating` and `val_star_rating`. While this could lead to multicollinearity in your eventual regression model, it is too early to clearly determine this at this point. Remember that multicollinearity is a relationship between 3 or more variables while correlation simply investigates the relationship between two variables.
#
# Additionally, these relationships provide an alternative method for imputing missing values: since they appear to be correlated, you could use these features to help impute missing values in the others features. For example, if you are missing the `star_rating` for a particular row but have the `val_star_rating` for that same entry, it seems reasonable to assume that it is a good estimate for the missing `star_rating` value as they are highly correlated. That said, doing so does come with risks; indeed you would be further increasing the correlation between these features which could further provoke multicollinearity in the final model.
#
# Investigate if you could use one of the other star rating features when one is missing. How many rows have one of `play_star_rating`, `star_rating` and `val_star_rating` missing, but not all three.

# %%
# Your code here
print('Number missing all three:',
      len(df[(df.play_star_rating.isnull())
      & (df.star_rating.isnull())
      & (df.val_star_rating.isnull())])
     )
# Number missing all three: 1421
# Out:
# Number missing all three: 1421

# %% [markdown]
# Well, it seems like when one is missing, the other two are also apt to be missing. While this has been a bit of an extended investigation, simply go ahead and fill the missing values with that feature's median. Fill in the missing values of `review_difficulty` feature  with string `'unknown'`.

# %%
# Your code here
df.play_star_rating = df.play_star_rating.fillna(value=df.play_star_rating.mean())
df.star_rating = df.star_rating.fillna(value=df.star_rating.mean())
df.val_star_rating = df.val_star_rating.fillna(value=df.val_star_rating.mean())
df.review_difficulty = df.review_difficulty.fillna(value='unknown')
df.prod_desc = df.prod_desc.fillna(value='unknown')
df.num_reviews = df.num_reviews.fillna(value=df.num_reviews.mean())

# %%
df.isna().sum()
# Out:
# prod_id              0
# ages                 0
# piece_count          0
# set_name             0
# prod_desc            0
# prod_long_desc       0
# theme_name           0
# country              0
# list_price           0
# num_reviews          0
# play_star_rating     0
# review_difficulty    0
# star_rating          0
# val_star_rating      0
# dtype: int64

# %% [markdown]
# ## Normalizing the Data
#
# Now, you'll need to convert all of our numeric columns to the same scale by **_normalizing_** our dataset.  Recall that you normalize a dataset by converting each numeric value to it's corresponding z-score for the column, which is obtained by subtracting the column's mean and then dividing by the column's standard deviation for every value.
#
#
# In the cell below:
#
# * Normalize the numeric X features by subtracting the column mean and dividing by the column standard deviation.
# (Don't bother to normalize the `list_price` as this is the feature you will be predicting.)

# %%
# Your code here
for column in df.columns:
    if column != 'list_price':
        if df[column].dtype != 'object':
            df[column] = [(x - df[column].mean())/df[column].std() for x in df[column]]

# %%
df.describe()
# Out:
#             prod_id   piece_count    list_price   num_reviews  \
# count  1.087000e+04  1.087000e+04  10870.000000  1.087000e+04
# mean   7.346801e-18  1.115789e-16     67.309137  7.566696e-15
# std    1.000000e+00  1.000000e+00     94.669414  1.000000e+00
# min   -3.523768e-01 -6.050659e-01      2.272400 -4.725030e-01
# 25%   -2.343560e-01 -4.895715e-01     21.899000 -4.162986e-01
# 50%   -1.137005e-01 -3.379852e-01     36.587800 -3.038898e-01
# 75%    5.431762e-02  6.263593e-02     73.187800  7.188413e-15
# max    1.116463e+01  8.466055e+00   1104.870000  9.812902e+00
#
#        play_star_rating   star_rating  val_star_rating
# count      1.087000e+04  1.087000e+04     1.087000e+04
# mean       1.390134e-13 -2.721965e-13    -7.025433e-14
# std        1.000000e+00  1.000000e+00     1.000000e+00
# min       -5.870245e+00 -5.628672e+00    -5.179606e+00
# 25%       -4.468405e-01 -4.367804e-01    -3.455381e-01
# 50%        7.800516e-02  1.862465e-01    -4.436632e-14
# 75%        6.028508e-01  8.092735e-01     6.212755e-01
# max        1.127696e+00  1.016949e+00     1.265818e+00

# %% [markdown]
# ## Saving Your Results
#
# While you'll once again practice one-hot encoding as you would to preprocess data before fitting a model, saving such a reperesentation of the data will eat up additional disk space. After all, a categorical variable with 10 bins will be transformed to 10 seperate features when passed through `pd.get_dummies()`. As such, while further practice is worthwhile, save your DataFrame as is for now.

# %%
# Your code here

# %% [markdown]
# ## One-Hot Encoding Categorical Columns
#
# As a final step, you'll need to deal with the categorical columns by **_one-hot encoding_** them into binary variables via the `pd.get_dummies()` function.
#
# When doing this, you may also need to subset the appropriate features to avoid encoding the wrong data. The `get_dummies()` function by default converts all columns with *object* or *category* dtype. However, you should always check the result of calling `get_dummies()` to ensure that only the categorical variables have been transformed. Consult the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html) for more details. If you are ever unsure of the data types, call the `.info()` method.
#
# In the cell below, subset to the appropriate predictive features and then use `pd.get_dummies()` to one-hot encode the dataset properly.

# %%
# Your code here

# %% [markdown]
# That's it! You've now successfully scrubbed your dataset -- you're now ready for data exploration and modeling!
#
# ## Summary
#
# In this lesson, you gained practice with data cleaning by:
#
# * Casting columns to the appropriate data types
# * Identifying and dealing with null values appropriately
# * Removing unnecessary columns
# * Checking for and dealing with multicollinearity
# * Normalizing your data
